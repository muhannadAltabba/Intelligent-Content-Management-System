# %%
# !pip install pytesseract
# !sudo apt install tesseract-ocr
# !sudo apt-get install tesseract-ocr-[ara]
# Out:
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'tesseract-ocr-afr' for regex 'tesseract-ocr-[ara]'
# Note, selecting 'tesseract-ocr-all' for regex 'tesseract-ocr-[ara]'
# Note, selecting 'tesseract-ocr-amh' for regex 'tesseract-ocr-[ara]'
# Note, selecting 'tesseract-ocr-ara' for regex 'tesseract-ocr-[ara]'
# Note, selecting 'tesseract-ocr-asm' for regex 'tesseract-ocr-[ara]'
# Note, selecting 'tesseract-ocr-aze' for regex 'tesseract-ocr-[ara]'
# Note, selecting 'tesseract-ocr-ron' for regex 'tesseract-ocr-[ara]'
# Note, selecting 'tesseract-ocr-rus' for regex 'tesseract-ocr-[ara]'
# Note, selecting 'tesseract-ocr-aze-cyrl' for regex 'tesseract-ocr-[ara]'
# ...

# %%
# !pip install pdf2image
# !sudo apt-get install poppler-utils
# Out:
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# poppler-utils is already the newest version (0.62.0-2ubuntu2.12).
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.

# %%
import pytesseract

# %%
# Import libraries
from PIL import Image
import pytesseract
import sys
from pdf2image import convert_from_path
import os

# %%
def ocr(path, lang = "ara", ocr_type = "img"):
  
  if ocr_type == "img":
    return pytesseract.image_to_string(path, lang= lang)

  elif ocr_type == "pdf":
    pages = convert_from_path(path, 500)
    image_counter = 1
    for page in pages:
        filename = "page_"+str(image_counter)+".jpg"
        # Save the image of the page in system
        page.save(filename, 'JPEG')
        # Increment the counter to update filename
        image_counter = image_counter + 1
    # Variable to get count of total number of pages
    filelimit = image_counter-1
    text = []
    # Iterate from 1 to total number of pages
    for i in range(1, filelimit + 1):
        filename = "page_"+str(i)+".jpg"
        text.append(str(((pytesseract.image_to_string(Image.open(filename), lang = "ara")))))
    return " ".join(text)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from google.colab.patches import cv2_imshow
import cv2
img = cv2.imread('/content/gdrive/MyDrive/ocr4.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x1280 at 0x7FB094F153D0>

# %%
print(ocr('/content/gdrive/MyDrive/ocr4.jpg', "ara"))
# Out:
# با صديقي لا أحد من اماق يستطيع أن يغضبك
# أو يحزنك دون إرادتك ما نس به في داخلك
# من مشاعى سلبية ليس بسبب ما يحدث حولك
# ولا برسالة منتقصة أو ازدراء عابر أو ظن سوء
# من بعيد أو جفاء من قريب كلا ما يحدتٌ في
# داخلك هو بسبب تايلك أنت للأمور من حولك
# وعندما تغير طريقة نظرك للأحداث ستتغير مشاعرك
# وتهدأً انفعالاتك حت بالنسبة للحدث ذاته .

# %%
print(ocr('/content/gdrive/MyDrive/ocr3.jpg', "eng"))
# Out:
# How to
# turn on text
# to speech

# %%
print(ocr("/content/gdrive/MyDrive/ocr.pdf", "ara", "pdf"))
# Out:
# نظام ذى يقدم خدمات إدارة المحتوى وباللغة العربية» فهو يقدم مجموعة من الخدمات الأساسية كعملية التخزين للبيانات
# وعرض المنشورات السابقة مع تاريخ نشرها والشخص الذي قام بعملية النخر, [1779995715:5155127159212998907891905
# 11077 كما أن النظام تميز بعدد من الخدمات عن باق أنظمة
# إدارة المحتوى كخدمة استخراج الكلمات المفتاحية من النصوص العربية. فقد لاحظنا افتقار الأنظمة المشابهة لدعم اللغة
# العربية. حيث يقوم النظام باستخراج الكلمات المفتاحية بشكل تلقائي فور انتهاء المستخدم من كتابة المنشور ويعرض له
# قائمة بالكلمات المفتاحية المناسبة ليختار منها ما يناسبه. بالإضافة لخدمة توليد شرح مناسب للصور وباللغة العربية» والني
# يستطيع المستخدم الاستفادة منها وباضافة هذا التوصيف لصفحة البرمجة الخاصة بصفحة الويب والتي ستمنح محركات
# البحث قدرة أكبر على تحديد محتوى الموقعء كما ويقدم النظام المقترح خدمة التعرف على وجوه الأشخاص الموجودين
# ضمن صورة وتعتبر هذه الخدمة مكملة لخدمة توليد شرح للصورة ةعلق تبك عن 7م51 امينة تين
# ...
